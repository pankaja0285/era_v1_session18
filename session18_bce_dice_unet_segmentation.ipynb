# %%
# !pip install pytorch-lightning
# Out:
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.0.9-py3-none-any.whl (727 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.7/727.7 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (1.23.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2.0.1+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.1.2-py3-none-any.whl (764 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.8/764.8 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.5.0)
# Collecting lightning-utilities>=0.7.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (16.0.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pytorch-lightning) (2.1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pytorch-lightning) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning
# Successfully installed lightning-utilities-0.9.0 pytorch-lightning-2.0.9 torchmetrics-1.1.2

# %%
import gc
import math
import glob
import os
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms.functional as TF
import torchvision.utils
import pytorch_lightning as pl
import torchmetrics as tm
import albumentations as A
from albumentations.pytorch import ToTensorV2
from typing import List
from PIL import Image

# %%
def set_seed(seed = 42):
    '''Sets the seed of the entire notebook so results are the same every time we run.
    This is for REPRODUCIBILITY.'''
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # When running on the CuDNN backend, two further options must be set
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    # Set a fixed value for the hash seed
    os.environ['PYTHONHASHSEED'] = str(seed)
    print('> SEEDING DONE')

set_seed()
# Out:
# > SEEDING DONE

# %%
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %%
# Check for GPU or setup TPU
# if not torch.cuda.is_available():
#     !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
#     !python pytorch-xla-env-setup.py --version 1.7 --apt-packages libomp5 libopenblas-dev
#     !pip install pytorch-lightning==1.1.5

# %% [markdown]
# # Model Architecture
#
# The following image depicts the architecture that will be used for segmentation. We will first define a torch module as the building block for the model, then use a pytorch lightning module to define the final model.
#
# ![](https://raw.githubusercontent.com/aladdinpersson/Machine-Learning-Collection/master/ML/Pytorch/image_segmentation/semantic_segmentation_unet/UNET_architecture.png)

# %%
# !git clone https://github.com/wemoveon2/SegLoss.git
# !cp -r SegLoss/losses_pytorch/* .
from dice_loss import GDiceLossV2, FocalTversky_loss
from hausdorff import HausdorffERLoss
# Out:
# Cloning into 'SegLoss'...
# remote: Enumerating objects: 494, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 494 (delta 85), reused 128 (delta 69), pack-reused 334
# Receiving objects: 100% (494/494), 457.25 KiB | 4.01 MiB/s, done.
# Resolving deltas: 100% (242/242), done.

# %%
ft_loss_args = {
    'apply_nonlin': F.sigmoid,
    'batch_dice': True,
}
hausdorff_er_loss = HausdorffERLoss()
generalized_dice_loss_v2 = GDiceLossV2(apply_nonlin=F.sigmoid)
ft_loss = FocalTversky_loss(ft_loss_args)

def loss_fn(pred, gt):
    return 0.5*hausdorff_er_loss(pred, gt) + 0.25*generalized_dice_loss_v2(pred, gt) + 0.25*ft_loss(pred, gt)

# %%
# !pip install segmentation_models_pytorch
import segmentation_models_pytorch as smp

BCELoss     = smp.losses.SoftBCEWithLogitsLoss()
TverskyLoss = smp.losses.TverskyLoss(mode='multilabel', log_loss=False)

@torch.no_grad()
def dice_coef(y_pred, y_true, thr=0.5, dim=(2,3), epsilon=0.001):
    y_t = y_true.to(torch.float32)
    y_p = (y_pred>thr).to(torch.float32)
    inter = (y_t*y_p).sum(dim=dim)
    den = y_t.sum(dim=dim) + y_p.sum(dim=dim)
    del y_t, y_p
    dice = ((2*inter+epsilon)/(den+epsilon)).mean(dim=(1,0))
    del inter, den
    return dice
@torch.no_grad()
def iou_coef(y_pred, y_true, thr=0.5, dim=(2,3), epsilon=0.001):
    y_t = y_true.to(torch.float32)
    y_p = (y_pred>thr).to(torch.float32)
    inter = (y_t*y_p).sum(dim=dim)
    union = (y_t + y_p - y_t*y_p).sum(dim=dim)
    del y_t, y_p
    iou = ((inter+epsilon)/(union+epsilon)).mean(dim=(1,0))
    del inter, union
    return iou

def loss_fn(y_pred, y_true):
    return 0.5*BCELoss(y_pred, y_true) + 0.5*TverskyLoss(y_pred, y_true)
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.3.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (0.15.2+cu118)
# Collecting pretrainedmodels==0.7.4 (from segmentation_models_pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting efficientnet-pytorch==0.7.1 (from segmentation_models_pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting timm==0.9.2 (from segmentation_models_pytorch)
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (4.66.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from segmentation_models_pytorch) (9.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.0.1+cu118)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation_models_pytorch)
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2->segmentation_models_pytorch) (6.0.1)
# Collecting huggingface-hub (from timm==0.9.2->segmentation_models_pytorch)
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 22.3 MB/s eta 0:00:00
# Collecting safetensors (from timm==0.9.2->segmentation_models_pytorch)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (2.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2->segmentation_models_pytorch) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation_models_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=ad52b9a32b8163219c068038bbd80a71b2b3f1c8359d39f1af96b28c07cd731f
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60943 sha256=b7c16add2fc262eb5aa2d2736212bb4012736d3914b2fef474024fc17d1831bb
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: safetensors, munch, huggingface-hub, timm, pretrainedmodels, efficientnet-pytorch, segmentation_models_pytorch
# Successfully installed efficientnet-pytorch-0.7.1 huggingface-hub-0.17.2 munch-4.0.0 pretrainedmodels-0.7.4 safetensors-0.3.3 segmentation_models_pytorch-0.3.3 timm-0.9.2

# %%
class DropBlock2D(nn.Module):
    r"""Randomly zeroes 2D spatial blocks of the input tensor.
    As described in the paper
    `DropBlock: A regularization method for convolutional networks`_ ,
    dropping whole blocks of feature map allows to remove semantic
    information as compared to regular dropout.
    Args:
        drop_prob (float): probability of an element to be dropped.
        block_size (int): size of the block to drop
    Shape:
        - Input: `(N, C, H, W)`
        - Output: `(N, C, H, W)`
    .. _DropBlock: A regularization method for convolutional networks:
       https://arxiv.org/abs/1810.12890
    """

    def __init__(self, drop_prob, block_size):
        super(DropBlock2D, self).__init__()
        self.drop_prob = drop_prob
        self.block_size = block_size

    def forward(self, x):
        # shape: (bsize, channels, height, width)
        assert x.dim() == 4, \
            "Expected input with 4 dimensions (bsize, channels, height, width)"
        if not self.training or self.drop_prob == 0.:
            return x
        else:
            # get gamma value
            gamma = self._compute_gamma(x)
            # sample mask
            mask = (torch.rand(x.shape[0], *x.shape[2:]) < gamma).float()
            # place mask on input device
            mask = mask.to(x.device)
            # compute block mask
            block_mask = self._compute_block_mask(mask)
            # apply block mask
            out = x * block_mask[:, None, :, :]
            # scale output
            out = out * block_mask.numel() / block_mask.sum()
            return out

    def _compute_block_mask(self, mask):
        block_mask = F.max_pool2d(input=mask[:, None, :, :],
                                  kernel_size=(self.block_size, self.block_size),
                                  stride=(1, 1),
                                  padding=self.block_size // 2)
        if self.block_size % 2 == 0:
            block_mask = block_mask[:, :, :-1, :-1]
        block_mask = 1 - block_mask.squeeze(1)
        return block_mask

    def _compute_gamma(self, x):
        return self.drop_prob / (self.block_size ** 2)

class Block(pl.LightningModule):
    def __init__(self, in_channels: int, out_channels: int, kernel: int = 3,
                 stride: int = 1, padding: int = 1, bias: bool = False, shortcut: bool = True):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel, stride, padding, bias=bias),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels, kernel, stride, padding, bias=bias),
            nn.BatchNorm2d(out_channels),
            DropBlock2D(0.8, 3)
        )
        if shortcut:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel, stride, padding, bias=bias),
                nn.BatchNorm2d(out_channels))
        else:
            self.shortcut = None
    def forward(self, x):
        identity = x
        out = self.conv(x)
        if self.expand_dims and self.shortcut is not None:
            identity = self.shortcut(identity)
        out += identity
        out = F.relu(out)
        return out

    def expand_dims(self):
        return self.in_channels != self.out_channels

class UNET(pl.LightningModule):
    def __init__(self, loss_fn, in_channels: int = 3, n_classes: int = 1,
                 features: List[int] = [64,128,256,512,1024], learning_rate: float = 1.5e-3):
        super().__init__()
        self.learning_rate = learning_rate
        self.down = nn.ModuleList()
        self.up = nn.ModuleList()
        self.pool = nn.MaxPool2d(2, 2)
        for feature in features:
            self.down.append(Block(in_channels, feature))
            in_channels=feature
        for feature in reversed(features):
            self.up.append(
                nn.ConvTranspose2d(feature*2, feature, 2, 2)
            )
            self.up.append(
                Block(feature*2, feature) # x gets concat to 2xchannel
            )
        self.bottleneck = Block(features[-1], features[-1]*2)
        self.final_conv = nn.Conv2d(features[0], n_classes, 1)
        self.loss_fn = loss_fn

        self.val_num_correct = 0
        self.val_num_pixels = 0
        self.val_dice_score = 0
        self.num_correct = 0
        self.num_pixels = 0
        self.dice_score = 0
    def forward(self, x):
        skip_connections = []
        for down in self.down:
            x = down(x)
            skip_connections.append(x)
            x = self.pool(x)
        x = self.bottleneck(x)
        skip_connections = skip_connections[::-1]
        for idx in range(0, len(self.up), 2):
            x = self.up[idx](x)
            skip_connection = skip_connections[idx//2]
            if x.shape != skip_connection.shape:
                x = TF.resize(x, size=skip_connection.shape[2:])
            concat_skip = torch.cat((skip_connection, x), dim=1) # Concat along channels (b, c, h, w)
            x = self.up[idx+1](concat_skip)
        return self.final_conv(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        y = y.float()  # Convert the target tensor to float
        pred = self(x)
        pred = pred.squeeze(dim=1)  # Remove the singleton dimension
        loss = self.loss_fn(pred, y)
        pred = torch.sigmoid(pred)
        pred = (pred > 0.5).float()
        self.num_correct += (pred == y).sum()
        self.num_pixels += torch.numel(pred)
        self.dice_score += (2 * (pred * y).sum()) / (
            (pred + y).sum() + 1e-8
        )
        self.log('train_loss', loss, prog_bar = True, logger = True)
        return {'loss': loss}

    def on_train_epoch_end(self):
        train_acc = float(f'{(self.num_correct/self.num_pixels)*100:.2f}')
        self.log('train_acc', train_acc, prog_bar = True, logger = True)
        num_training_batches = self.trainer.num_training_batches or 1
        dice_score = self.dice_score / num_training_batches
        self.log('train_dice_score', dice_score, prog_bar = True, logger = True)
        self.num_correct, self.num_pixels, self.dice_score = 0,0,0

    def validation_step(self, batch, batch_idx):
        x, y = batch
        y = y.float()  # Convert the target tensor to float
        pred = self(x)
        pred = pred.squeeze(dim=1)  # Remove the singleton dimension
        loss = self.loss_fn(pred, y)
        pred = torch.sigmoid(pred)
        pred = (pred > 0.5).float()
        self.val_num_correct += (pred == y).sum()
        self.val_num_pixels += torch.numel(pred)
        self.val_dice_score += (2 * (pred * y).sum()) / (
            (pred + y).sum() + 1e-8
        )
        self.log('val_loss', loss, prog_bar = True, logger = True)
        return {'loss': loss}

    def on_validation_epoch_end(self):
        val_acc = float(f'{(self.val_num_correct/self.val_num_pixels)*100:.2f}')
        self.log('val_acc', val_acc, prog_bar = True, logger = True)
        num_val_batches = self.trainer.num_val_batches[0] if self.trainer.num_val_batches else 1
        dice_score = self.val_dice_score/num_val_batches
        self.log('val_dice_score', dice_score, prog_bar = True, logger = True)
        self.val_num_correct, self.val_num_pixels, self.val_dice_score = 0,0,0

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(params = self.parameters(), lr = self.learning_rate, weight_decay=0.3)
        return optimizer

# %% [markdown]
# We can see how many parameters we have in our model using the following command. Note that the order shown does not reflect how a training example flows through the architecture.

# %%
# pl.utilities.model_summary.summarize(UNET(),-1)

# %% [markdown]
# # Data
# Now that we have our model, we define a torch Dataset to retrieve and apply our transformations to our data. We define the three necessary methods and move on to defining our LightningDataModule, which will split our Dataset into train/val splits and prepare the appropriate Dataloader when called by the Trainer object later on when we start training.

# %%
import cv2
from torchvision.datasets import VOCSegmentation
class VOCSegmentationDataModule(pl.LightningDataModule):

    def __init__(self, data_dir: str = './data', batch_size: int = 32):
        super().__init__()
        self.data_dir = data_dir
        self.batch_size = batch_size

        # Define the albumentations transform
        self.transform = A.Compose([
            A.Resize(128, 128),
            A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
            ToTensorV2(),
        ])

    def setup(self, stage=None):
        # Load the training and validation datasets with the transform
        self.train_dataset = VOCSegmentation(root=self.data_dir, year='2012', image_set='train', download=True, transforms=self._wrapped_transform())
        self.val_dataset = VOCSegmentation(root=self.data_dir, year='2012', image_set='val', download=True, transforms=self._wrapped_transform())

    def train_dataloader(self):
        return DataLoader(self.train_dataset, batch_size=self.batch_size, shuffle=True)

    def val_dataloader(self):
        return DataLoader(self.val_dataset, batch_size=self.batch_size, shuffle=False)

    def _wrapped_transform(self):
        # Wrap the albumentations transform to make it compatible with VOCSegmentation
        class WrappedTransform:
            def __init__(self, transform):
                self.transform = transform

            def __call__(self, img, target):
                transformed = self.transform(image=np.array(img), mask=np.array(target))
                return transformed['image'], transformed['mask']

        return WrappedTransform(self.transform)

# %% [markdown]
# # Training
#
# Once our model, optimizer+loss, and LightningDataModule is defined, we can use Trainer to run our training and validation loops. We can also use callbacks provided by lightning (check out [Bolts](https://lightning-bolts.readthedocs.io/en/latest/) for advanced callbacks, such as for sparsification) to create checkpoints or for early stopping. Trainer also takes care of multi-GPU and TPU training.
#
# We also use albumentations to apply the **same** data augmentations on the image **and** mask. I don't believe the torchvision transforms allows you to do the same, but correct me if I'm wrong.

# %%
# Instantiate the DataModule
voc_data_module = VOCSegmentationDataModule(data_dir='./data', batch_size=32)

# %%
torch.cuda.empty_cache()
# transform = A.Compose(
#     [
#         A.Resize(height=255, width=255),
#         A.Rotate(limit=45, p=0.7),
#         A.HorizontalFlip(p=0.5),
#         A.VerticalFlip(p=0.3),
#         A.Normalize(
#             mean=[0.0, 0.0, 0.0],
#             std=[1.0, 1.0, 1.0],
#             max_pixel_value=255.0,
#         ),
#         A.pytorch.ToTensorV2(),
#     ]
# )
args = {
    'in_channels': 3,
    'n_classes': 1,
    'features': [64,128,256,512,1024],
    'loss_fn': loss_fn
}

model = UNET(**args)
if not os.path.isdir('./unet_model'): os.mkdir('./unet_model')
checkpointCallback = pl.callbacks.ModelCheckpoint(dirpath="./unet_model",
                                                  save_top_k=1,
                                                  monitor="val_loss",
                                                 filename='{epoch}-{val_loss:.5f}',
                                                 mode='min')
if torch.cuda.is_available():
    trainer = pl.Trainer(max_epochs=8, accelerator='auto',
                         callbacks=[checkpointCallback], profiler='simple',
                         accumulate_grad_batches=20)
else:
    trainer = pl.Trainer(max_epochs=40, accelerator='tpu',
                         callbacks=[checkpointCallback], auto_lr_find=True)

trainer.fit(model, datamodule=voc_data_module)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Using downloaded and verified file: ./data/VOCtrainval_11-May-2012.tar
# Extracting ./data/VOCtrainval_11-May-2012.tar to ./data
# Using downloaded and verified file: ./data/VOCtrainval_11-May-2012.tar
# Extracting ./data/VOCtrainval_11-May-2012.tar to ./data
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:617: UserWarning: Checkpoint directory /content/unet_model exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name       | Type       | Params
# ------------------------------------------
# 0 | down       | ModuleList | 25.1 M
# 1 | up         | ModuleList | 74.0 M
# 2 | pool       | MaxPool2d  | 0
# 3 | bottleneck | Block      | 75.5 M
# 4 | final_conv | Conv2d     | 65
# ------------------------------------------
# 174 M     Trainable params
# 0         Non-trainable params
# 174 M     Total params
# 698.682   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=8` reached.
# INFO:pytorch_lightning.profilers.profiler:FIT Profiler Report
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                               	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                	|  -              	|  14948          	|  560.81         	|  100 %          	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                   	|  52.33          	|  8              	|  418.64         	|  74.649         	|
# |  run_training_batch                                                                                                                                                   	|  0.25623        	|  368            	|  94.292         	|  16.814         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                         	|  0.24501        	|  368            	|  90.165         	|  16.078         	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end       	|  9.7081         	|  8              	|  77.665         	|  13.849         	|
# |  [LightningDataModule]VOCSegmentationDataModule.setup                                                                                                                 	|  61.9           	|  1              	|  61.9           	|  11.038         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                           	|  0.15839        	|  368            	|  58.289         	|  10.394         	|
# |  [_EvaluationLoop].val_next                                                                                                                                           	|  0.14994        	|  371            	|  55.627         	|  9.919          	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                       	|  0.043626       	|  738            	|  32.196         	|  5.7409         	|
# |  [LightningModule]UNET.transfer_batch_to_device                                                                                                                       	|  0.043507       	|  738            	|  32.108         	|  5.7253         	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                         	|  0.033189       	|  368            	|  12.213         	|  2.1778         	|
# |  [LightningModule]UNET.optimizer_step                                                                                                                                 	|  0.25071        	|  24             	|  6.0172         	|  1.0729         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                              	|  0.010515       	|  368            	|  3.8693         	|  0.68996        	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                       	|  0.0088284      	|  370            	|  3.2665         	|  0.58246        	|
# |  [LightningModule]UNET.on_validation_epoch_end                                                                                                                        	|  0.027408       	|  9              	|  0.24667        	|  0.043985       	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                        	|  0.021442       	|  9              	|  0.19298        	|  0.03441        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                    	|  0.00015383     	|  370            	|  0.056916       	|  0.010149       	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                          	|  0.0028727      	|  9              	|  0.025854       	|  0.0046101      	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                             	|  0.025659       	|  1              	|  0.025659       	|  0.0045754      	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                  	|  5.7775e-05     	|  370            	|  0.021377       	|  0.0038118      	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                      	|  0.016528       	|  1              	|  0.016528       	|  0.0029471      	|
# |  [LightningModule]UNET.on_train_epoch_end                                                                                                                             	|  0.0019679      	|  8              	|  0.015743       	|  0.0028072      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end       	|  3.9102e-05     	|  368            	|  0.014389       	|  0.0025658      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                       	|  0.0016613      	|  8              	|  0.01329        	|  0.0023698      	|
# |  [LightningModule]UNET.optimizer_zero_grad                                                                                                                            	|  0.00034344     	|  24             	|  0.0082426      	|  0.0014698      	|
# |  [LightningModule]UNET.on_validation_model_eval                                                                                                                       	|  0.00086847     	|  9              	|  0.0078162      	|  0.0013937      	|
# |  [LightningModule]UNET.on_validation_model_train                                                                                                                      	|  0.00082635     	|  9              	|  0.0074371      	|  0.0013261      	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                  	|  0.0046523      	|  1              	|  0.0046523      	|  0.00082957     	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                         	|  0.00043571     	|  8              	|  0.0034857      	|  0.00062154     	|
# |  [LightningModule]UNET.on_before_batch_transfer                                                                                                                       	|  3.427e-06      	|  738            	|  0.0025291      	|  0.00045097     	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                          	|  5.2942e-06     	|  368            	|  0.0019483      	|  0.0003474      	|
# |  [LightningModule]UNET.on_after_batch_transfer                                                                                                                        	|  2.0397e-06     	|  738            	|  0.0015053      	|  0.00026841     	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                         	|  3.7238e-06     	|  368            	|  0.0013704      	|  0.00024435     	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                       	|  3.3714e-06     	|  368            	|  0.0012407      	|  0.00022123     	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                       	|  2.9143e-06     	|  370            	|  0.0010783      	|  0.00019228     	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                            	|  2.5815e-06     	|  368            	|  0.00094999     	|  0.0001694      	|
# |  [LightningModule]UNET.configure_optimizers                                                                                                                           	|  0.00093691     	|  1              	|  0.00093691     	|  0.00016706     	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                     	|  2.403e-06      	|  370            	|  0.00088911     	|  0.00015854     	|
# |  [LightningModule]UNET.configure_gradient_clipping                                                                                                                    	|  3.6033e-05     	|  24             	|  0.0008648      	|  0.00015421     	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                            	|  2.1779e-06     	|  368            	|  0.00080147     	|  0.00014291     	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                               	|  0.00079785     	|  1              	|  0.00079785     	|  0.00014227     	|
# |  [LightningModule]UNET.on_after_backward                                                                                                                              	|  1.825e-06      	|  368            	|  0.00067159     	|  0.00011975     	|
# |  [LightningModule]UNET.on_validation_batch_end                                                                                                                        	|  1.704e-06      	|  370            	|  0.00063046     	|  0.00011242     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_end  	|  1.6808e-06     	|  370            	|  0.00062191     	|  0.0001109      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_start	|  1.6755e-06     	|  370            	|  0.00061993     	|  0.00011054     	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                             	|  1.6325e-06     	|  368            	|  0.00060078     	|  0.00010713     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward        	|  1.5989e-06     	|  368            	|  0.00058838     	|  0.00010492     	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                          	|  1.5969e-06     	|  368            	|  0.00058765     	|  0.00010479     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start     	|  1.5224e-06     	|  368            	|  0.00056024     	|  9.9898e-05     	|
# |  [LightningModule]UNET.on_before_backward                                                                                                                             	|  1.5198e-06     	|  368            	|  0.00055928     	|  9.9727e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                    	|  0.00055334     	|  1              	|  0.00055334     	|  9.8668e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward       	|  1.4937e-06     	|  368            	|  0.00054967     	|  9.8014e-05     	|
# |  [LightningModule]UNET.on_train_batch_start                                                                                                                           	|  1.4929e-06     	|  368            	|  0.00054938     	|  9.7961e-05     	|
# |  [LightningModule]UNET.on_validation_batch_start                                                                                                                      	|  1.4561e-06     	|  370            	|  0.00053876     	|  9.6068e-05     	|
# |  [LightningModule]UNET.on_train_batch_end                                                                                                                             	|  1.4012e-06     	|  368            	|  0.00051565     	|  9.1948e-05     	|
# |  [LightningDataModule]VOCSegmentationDataModule.val_dataloader                                                                                                        	|  0.00044278     	|  1              	|  0.00044278     	|  7.8954e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                  	|  1.1585e-06     	|  368            	|  0.00042634     	|  7.6023e-05     	|
# |  [LightningDataModule]VOCSegmentationDataModule.train_dataloader                                                                                                      	|  0.00036888     	|  1              	|  0.00036888     	|  6.5777e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end        	|  4.0779e-05     	|  9              	|  0.00036701     	|  6.5443e-05     	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                        	|  3.8616e-06     	|  24             	|  9.2678e-05     	|  1.6526e-05     	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                   	|  2.9527e-06     	|  24             	|  7.0864e-05     	|  1.2636e-05     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                           	|  6.8474e-06     	|  9              	|  6.1627e-05     	|  1.0989e-05     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                             	|  6.5289e-06     	|  9              	|  5.876e-05      	|  1.0478e-05     	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                           	|  1.9765e-06     	|  24             	|  4.7435e-05     	|  8.4583e-06     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                    	|  5.2068e-06     	|  9              	|  4.6861e-05     	|  8.3559e-06     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                          	|  4.7734e-06     	|  8              	|  3.8187e-05     	|  6.8093e-06     	|
# |  [LightningModule]UNET.on_before_zero_grad                                                                                                                            	|  1.4571e-06     	|  24             	|  3.497e-05      	|  6.2356e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad      	|  1.438e-06      	|  24             	|  3.4513e-05     	|  6.1541e-06     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                            	|  4.189e-06      	|  8              	|  3.3512e-05     	|  5.9756e-06     	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                      	|  1.3642e-06     	|  24             	|  3.274e-05      	|  5.838e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step 	|  1.3043e-06     	|  24             	|  3.1304e-05     	|  5.5819e-06     	|
# |  [LightningModule]UNET.on_before_optimizer_step                                                                                                                       	|  1.2539e-06     	|  24             	|  3.0093e-05     	|  5.366e-06      	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                  	|  2.3651e-06     	|  9              	|  2.1286e-05     	|  3.7956e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start      	|  2.1867e-06     	|  9              	|  1.968e-05      	|  3.5092e-06     	|
# |  [LightningModule]UNET.on_validation_end                                                                                                                              	|  2.0677e-06     	|  9              	|  1.8609e-05     	|  3.3182e-06     	|
# |  [LightningModule]UNET.on_validation_start                                                                                                                            	|  1.8709e-06     	|  9              	|  1.6838e-05     	|  3.0024e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                       	|  1.8338e-06     	|  9              	|  1.6504e-05     	|  2.9429e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end  	|  1.7999e-06     	|  9              	|  1.6199e-05     	|  2.8885e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                     	|  1.7932e-06     	|  9              	|  1.6139e-05     	|  2.8778e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start	|  1.7813e-06     	|  9              	|  1.6032e-05     	|  2.8587e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start     	|  1.9125e-06     	|  8              	|  1.53e-05       	|  2.7282e-06     	|
# |  [LightningModule]UNET.on_validation_epoch_start                                                                                                                      	|  1.6053e-06     	|  9              	|  1.4448e-05     	|  2.5763e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                   	|  1.528e-06      	|  9              	|  1.3752e-05     	|  2.4522e-06     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                         	|  6.742e-06      	|  2              	|  1.3484e-05     	|  2.4044e-06     	|
# |  [LightningModule]UNET.on_train_epoch_start                                                                                                                           	|  1.6421e-06     	|  8              	|  1.3137e-05     	|  2.3425e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                     	|  1.4136e-06     	|  9              	|  1.2722e-05     	|  2.2685e-06     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                        	|  8.158e-06      	|  1              	|  8.158e-06      	|  1.4547e-06     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                	|  7.973e-06      	|  1              	|  7.973e-06      	|  1.4217e-06     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                      	|  7.571e-06      	|  1              	|  7.571e-06      	|  1.35e-06       	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                         	|  7.274e-06      	|  1              	|  7.274e-06      	|  1.2971e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                 	|  6.593e-06      	|  1              	|  6.593e-06      	|  1.1756e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start             	|  6.073e-06      	|  1              	|  6.073e-06      	|  1.0829e-06     	|
# |  [LightningDataModule]VOCSegmentationDataModule.state_dict                                                                                                            	|  2.8085e-06     	|  2              	|  5.617e-06      	|  1.0016e-06     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                  	|  4.734e-06      	|  1              	|  4.734e-06      	|  8.4414e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start           	|  4.602e-06      	|  1              	|  4.602e-06      	|  8.206e-07      	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                               	|  4.472e-06      	|  1              	|  4.472e-06      	|  7.9742e-07     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                            	|  1.9735e-06     	|  2              	|  3.947e-06      	|  7.038e-07      	|
# |  [LightningModule]UNET.configure_callbacks                                                                                                                            	|  3.901e-06      	|  1              	|  3.901e-06      	|  6.956e-07      	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                           	|  3.289e-06      	|  1              	|  3.289e-06      	|  5.8647e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint       	|  1.5985e-06     	|  2              	|  3.197e-06      	|  5.7007e-07     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                   	|  3.166e-06      	|  1              	|  3.166e-06      	|  5.6454e-07     	|
# |  [Callback]ModelSummary.setup                                                                                                                                         	|  2.56e-06       	|  1              	|  2.56e-06       	|  4.5648e-07     	|
# |  [LightningModule]UNET.on_fit_start                                                                                                                                   	|  2.532e-06      	|  1              	|  2.532e-06      	|  4.5149e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start    	|  2.522e-06      	|  1              	|  2.522e-06      	|  4.4971e-07     	|
# |  [LightningModule]UNET.on_train_start                                                                                                                                 	|  2.476e-06      	|  1              	|  2.476e-06      	|  4.415e-07      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end             	|  2.33e-06       	|  1              	|  2.33e-06       	|  4.1547e-07     	|
# |  [LightningDataModule]VOCSegmentationDataModule.teardown                                                                                                              	|  2.287e-06      	|  1              	|  2.287e-06      	|  4.078e-07      	|
# |  [LightningModule]UNET.setup                                                                                                                                          	|  2.189e-06      	|  1              	|  2.189e-06      	|  3.9033e-07     	|
# |  [LightningModule]UNET.on_save_checkpoint                                                                                                                             	|  1.0825e-06     	|  2              	|  2.165e-06      	|  3.8605e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end      	|  2.085e-06      	|  1              	|  2.085e-06      	|  3.7178e-07     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                    	|  2.068e-06      	|  1              	|  2.068e-06      	|  3.6875e-07     	|
# |  [LightningModule]UNET.on_fit_end                                                                                                                                     	|  2.049e-06      	|  1              	|  2.049e-06      	|  3.6536e-07     	|
# |  [LightningModule]UNET.on_train_end                                                                                                                                   	|  2.002e-06      	|  1              	|  2.002e-06      	|  3.5698e-07     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                      	|  1.976e-06      	|  1              	|  1.976e-06      	|  3.5235e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end               	|  1.939e-06      	|  1              	|  1.939e-06      	|  3.4575e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                 	|  1.937e-06      	|  1              	|  1.937e-06      	|  3.4539e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                        	|  1.758e-06      	|  1              	|  1.758e-06      	|  3.1348e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                          	|  1.523e-06      	|  1              	|  1.523e-06      	|  2.7157e-07     	|
# |  [LightningDataModule]VOCSegmentationDataModule.prepare_data                                                                                                          	|  1.52e-06       	|  1              	|  1.52e-06       	|  2.7104e-07     	|
# |  [LightningModule]UNET.teardown                                                                                                                                       	|  1.392e-06      	|  1              	|  1.392e-06      	|  2.4821e-07     	|
# |  [LightningModule]UNET.configure_sharded_model                                                                                                                        	|  1.267e-06      	|  1              	|  1.267e-06      	|  2.2592e-07     	|
# |  [LightningModule]UNET.prepare_data                                                                                                                                   	|  8.28e-07       	|  1              	|  8.28e-07       	|  1.4764e-07     	|
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Utility Functions
#
# Here we define three utility functions:
#   1. **save_images**(model, loader, folder, device)
#       - This is used to save predictions and their corresponding masks from a specified model across a specified dataloader.
#       - Device can be set to cpu if not running on gpu
#   2. **get_concat_v**(im1, im2)
#       - This is used to later concatenate the prediction and mask images we create using save_image.
#       - im1 & im2 are PIL.Image objects
#   3. **merge_photos**(src_folder, dst_folder, remove_single)
#       - This is used to read and concatenate the prediction and mask images using the previously defined get_concat_v().
#       - remove_single can be set to False to save the unmerged images

# %%
def save_images(model, loader, folder='val_img', device='cuda'):
    model.eval()
    if not os.path.isdir(folder):
        os.mkdir(folder)
    model.to(device=device)
    for idx, (x, y) in enumerate(loader):
        x = x.to(device=device)
        y = y.to(device=device)
        with torch.no_grad():
            preds = torch.sigmoid(model(x).cuda())
            preds = (preds > 0.5).float()
        torchvision.utils.save_image(
            preds, f"{folder}/pred_{idx}.png"
        )
        torchvision.utils.save_image(y, f"{folder}/mask_{idx}.png")

def get_concat_v(im1, im2):
    dst = Image.new('RGB', (im1.width, im1.height + im2.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (0, im1.height))
    return dst

def merge_photos(src_folder: str='./val_img', dst_folder: str='./merged_val_img', remove_single: bool=True):
    files = glob.glob(src_folder+'/*.png')
    if not os.path.isdir(dst_folder):
        os.mkdir(dst_folder)
    for i in range(int(len(files)/2)):
        pred_img = Image.open(f'{src_folder}/pred_{i}.png')
        mask_img = Image.open(f'{src_folder}/mask_{i}.png')
        get_concat_v(pred_img, mask_img).save(f'{dst_folder}/merged_pred_mask_{i}.png')
        if remove_single:
            os.remove(f'./val_img/pred_{i}.png')
            os.remove(f'./val_img/mask_{i}.png')

# %%
ds = SegmentationDataModule('../input/carvana-image-masking-png/train_images', '../input/carvana-image-masking-png/train_masks', transform=data_transforms['valid'])
ds.setup()
save_images(model, ds.val_dataloader())
merge_photos()
# TODO: Implement feature for sampling random img/label pairs for model prediction/eval
#         - Should show output and mask as images, pref side by side or across batches
#         - Conduct additional testing using the competition or data from the internet

# %%
# !zip -r lightning_logs.zip ./lightning_logs
# !zip -r merged_val_img.zip ./merged_val_img
# !zip -r unet.zip ./unet_model
# Out:
#   adding: lightning_logs/ (stored 0%)
#   adding: lightning_logs/version_0/ (stored 0%)
#   adding: lightning_logs/version_0/hparams.yaml (stored 0%)
#   adding: lightning_logs/version_0/events.out.tfevents.1657398734.e00bbb48e8c2.23.0 (deflated 61%)
#   adding: merged_val_img/ (stored 0%)
#   adding: merged_val_img/merged_pred_mask_89.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_48.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_41.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_44.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_79.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_56.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_28.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_97.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_85.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_86.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_25.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_76.png (deflated 13%)
#   adding: merged_val_img/merged_pred_mask_17.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_75.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_77.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_37.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_33.png (deflated 13%)
#   adding: merged_val_img/merged_pred_mask_8.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_46.png (deflated 8%)
#   adding: merged_val_img/merged_pred_mask_45.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_39.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_64.png (deflated 13%)
#   adding: merged_val_img/merged_pred_mask_73.png (deflated 13%)
#   adding: merged_val_img/merged_pred_mask_14.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_69.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_0.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_3.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_32.png (deflated 8%)
#   adding: merged_val_img/merged_pred_mask_19.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_43.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_24.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_94.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_21.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_38.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_100.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_70.png (deflated 14%)
#   adding: merged_val_img/merged_pred_mask_58.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_53.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_15.png (deflated 13%)
#   adding: merged_val_img/merged_pred_mask_9.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_60.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_99.png (deflated 7%)
#   adding: merged_val_img/merged_pred_mask_71.png (deflated 13%)
#   adding: merged_val_img/merged_pred_mask_10.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_78.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_22.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_6.png (deflated 8%)
#   adding: merged_val_img/merged_pred_mask_51.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_30.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_47.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_5.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_91.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_16.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_95.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_93.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_92.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_90.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_87.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_65.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_1.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_72.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_88.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_62.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_80.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_29.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_49.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_82.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_42.png (deflated 8%)
#   adding: merged_val_img/merged_pred_mask_34.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_12.png (deflated 7%)
#   adding: merged_val_img/merged_pred_mask_74.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_59.png (deflated 14%)
#   adding: merged_val_img/merged_pred_mask_20.png (deflated 8%)
#   adding: merged_val_img/merged_pred_mask_68.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_13.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_35.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_50.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_67.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_66.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_83.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_54.png (deflated 7%)
#   adding: merged_val_img/merged_pred_mask_27.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_84.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_36.png (deflated 7%)
#   adding: merged_val_img/merged_pred_mask_18.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_11.png (deflated 11%)
#   adding: merged_val_img/merged_pred_mask_57.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_55.png (deflated 8%)
#   adding: merged_val_img/merged_pred_mask_26.png (deflated 14%)
#   adding: merged_val_img/merged_pred_mask_40.png (deflated 13%)
#   adding: merged_val_img/merged_pred_mask_23.png (deflated 8%)
#   adding: merged_val_img/merged_pred_mask_81.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_96.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_2.png (deflated 9%)
#   adding: merged_val_img/merged_pred_mask_31.png (deflated 13%)
#   adding: merged_val_img/merged_pred_mask_63.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_52.png (deflated 8%)
#   adding: merged_val_img/merged_pred_mask_98.png (deflated 12%)
#   adding: merged_val_img/merged_pred_mask_61.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_101.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_7.png (deflated 10%)
#   adding: merged_val_img/merged_pred_mask_4.png (deflated 8%)
#   adding: unet_model/ (stored 0%)
#   adding: unet_model/epoch=7-val_loss=0.04044.ckpt (deflated 8%)
